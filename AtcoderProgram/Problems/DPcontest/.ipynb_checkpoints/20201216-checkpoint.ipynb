// %%
#include<bits/stdc++.h>
using namespace std;

// %% [markdown]
// # D Knapsack 1

// %%
int number, limit;
cin >> number >> limit;
vector<int> weight(number);
vector<int> values(number);
for (int i = 0 ; i < number ;i++) cin >> weight.at(i) >> values.at(i);
vector<vector<int>> dp(number+1,vector<int>(100010));

int scoreFromCurrent;
int weightFromCurrent;
for (int i = 0 ; i < number ; i++){
    for (int sumWeight = 0; sumWeight <= limit ; sumWeight++){
        weightFromCurrent = weight.at(i)+sumWeight;
        if (weightFromCurrent <= limit){
            // compare the current dp score and score from current dp
            scoreFromCurrent = dp.at(i).at(sumWeight) + values.at(i);
            dp.at(i+1).at(weightFromCurrent) = max(dp.at(i+1).at(weightFromCurrent),
                                                   scoreFromCurrent);
        }
        dp.at(i+1).at(sumWeight) = max(dp.at(i+1).at(sumWeight),dp.at(i).at(sumWeight));
    }
}
// Out:
// input_line_10:4:13: error: no matching constructor for initialization of 'vector<int>'
// vector<int> weight(number);
//             ^      ~~~~~~
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:270:7: note: candidate constructor not viable: no known conversion from 'int' to 'const std::vector<int, std::allocator<int> >::allocator_type' (aka 'const std::allocator<int>') for 1st argument
//       vector(const allocator_type& __a) _GLIBCXX_NOEXCEPT
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:344:7: note: candidate constructor not viable: no known conversion from 'int' to 'std::vector<int, std::allocator<int> >' for 1st argument
//       vector(vector&& __x) noexcept
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:383:7: note: candidate constructor not viable: no known conversion from 'int' to 'initializer_list<std::vector<int, std::allocator<int> >::value_type>' (aka 'initializer_list<int>') for 1st argument
//       vector(initializer_list<value_type> __l,
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:411:2: note: candidate constructor template not viable: requires at least 2 arguments, but 1 was provided
//         vector(_InputIterator __first, _InputIterator __last,
//         ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:259:7: note: candidate constructor not viable: requires 0 arguments, but 1 was provided
//       vector()
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:348:7: note: candidate constructor not viable: requires 2 arguments, but 1 was provided
//       vector(const vector& __x, const allocator_type& __a)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:358:7: note: candidate constructor not viable: requires 2 arguments, but 1 was provided
//       vector(vector&& __rv, const allocator_type& __m)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:295:7: note: candidate constructor not viable: requires at least 2 arguments, but 1 was provided
//       vector(size_type __n, const value_type& __value,
//       ^
// input_line_10:5:13: error: no matching constructor for initialization of 'vector<int>'
// vector<int> values(number);
//             ^      ~~~~~~
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:270:7: note: candidate constructor not viable: no known conversion from 'int' to 'const std::vector<int, std::allocator<int> >::allocator_type' (aka 'const std::allocator<int>') for 1st argument
//       vector(const allocator_type& __a) _GLIBCXX_NOEXCEPT
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:344:7: note: candidate constructor not viable: no known conversion from 'int' to 'std::vector<int, std::allocator<int> >' for 1st argument
//       vector(vector&& __x) noexcept
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:383:7: note: candidate constructor not viable: no known conversion from 'int' to 'initializer_list<std::vector<int, std::allocator<int> >::value_type>' (aka 'initializer_list<int>') for 1st argument
//       vector(initializer_list<value_type> __l,
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:411:2: note: candidate constructor template not viable: requires at least 2 arguments, but 1 was provided
//         vector(_InputIterator __first, _InputIterator __last,
//         ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:259:7: note: candidate constructor not viable: requires 0 arguments, but 1 was provided
//       vector()
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:348:7: note: candidate constructor not viable: requires 2 arguments, but 1 was provided
//       vector(const vector& __x, const allocator_type& __a)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:358:7: note: candidate constructor not viable: requires 2 arguments, but 1 was provided
//       vector(vector&& __rv, const allocator_type& __m)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:295:7: note: candidate constructor not viable: requires at least 2 arguments, but 1 was provided
//       vector(size_type __n, const value_type& __value,
//       ^
// input_line_10:7:33: error: no matching conversion for functional-style cast from 'int' to 'vector<int>'
// vector<vector<int>> dp(number+1,vector<int>(100010));
//                                 ^~~~~~~~~~~~~~~~~~
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:270:7: note: candidate constructor not viable: no known conversion from 'int' to 'const std::vector<int, std::allocator<int> >::allocator_type' (aka 'const std::allocator<int>') for 1st argument
//       vector(const allocator_type& __a) _GLIBCXX_NOEXCEPT
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:344:7: note: candidate constructor not viable: no known conversion from 'int' to 'std::vector<int, std::allocator<int> >' for 1st argument
//       vector(vector&& __x) noexcept
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:383:7: note: candidate constructor not viable: no known conversion from 'int' to 'initializer_list<std::vector<int, std::allocator<int> >::value_type>' (aka 'initializer_list<int>') for 1st argument
//       vector(initializer_list<value_type> __l,
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:411:2: note: candidate constructor template not viable: requires at least 2 arguments, but 1 was provided
//         vector(_InputIterator __first, _InputIterator __last,
//         ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:259:7: note: candidate constructor not viable: requires 0 arguments, but 1 was provided
//       vector()
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:348:7: note: candidate constructor not viable: requires 2 arguments, but 1 was provided
//       vector(const vector& __x, const allocator_type& __a)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:358:7: note: candidate constructor not viable: requires 2 arguments, but 1 was provided
//       vector(vector&& __rv, const allocator_type& __m)
//       ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:295:7: note: candidate constructor not viable: requires at least 2 arguments, but 1 was provided
//       vector(size_type __n, const value_type& __value,
//       ^
// input_line_10:16:46: error: cannot assign to return value because function 'at' returns a const value
//             dp.at(i+1).at(weightFromCurrent) = max(dp.at(i+1).at(weightFromCurrent),
//             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:861:7: note: function 'at' which returns const-qualified type 'std::vector<int, std::allocator<int> >::const_reference' (aka 'const int &') declared here
//       const_reference
//       ^~~~~~~~~~~~~~~
// input_line_10:19:34: error: cannot assign to return value because function 'at' returns a const value
//         dp.at(i+1).at(sumWeight) = max(dp.at(i+1).at(sumWeight),dp.at(i).at(sumWeight));
//         ~~~~~~~~~~~~~~~~~~~~~~~~ ^
// /opt/conda/bin/../lib/gcc/x86_64-conda-linux-gnu/7.5.0/../../../../x86_64-conda-linux-gnu/include/c++/7.5.0/bits/stl_vector.h:861:7: note: function 'at' which returns const-qualified type 'std::vector<int, std::allocator<int> >::const_reference' (aka 'const int &') declared here
//       const_reference
//       ^~~~~~~~~~~~~~~
// Interpreter Error:
